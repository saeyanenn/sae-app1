# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = np.random.randint(0,50,size=(2,100))
data[:5]
# Out:
# array([[45, 35, 19, 23, 25,  0,  9,  8,  9, 48, 42, 40,  9, 28, 17, 16,
#         26, 44, 24, 20, 35,  9, 16, 25,  7, 16,  2, 42,  1,  7, 22, 14,
#         24, 13, 43, 32, 38,  4, 21, 16, 39, 15,  5, 37, 30, 37, 30, 47,
#         12,  9, 37, 30, 36, 37,  5, 23, 21, 33, 11, 24, 42, 36, 32, 26,
#          9, 28, 32, 41,  2, 23, 40, 40, 34, 16, 37,  3, 39, 11, 19, 35,
#         37,  3, 32, 20,  0, 37, 33, 31, 13, 31, 13,  6, 43, 14, 30, 17,
#         15, 30, 12, 22],
#        [24, 18,  6, 38, 10, 28,  1,  8,  8, 22, 43, 47, 32, 23, 25, 37,
#         27,  3,  7, 28,  5,  4, 39, 10, 10,  6, 25,  8, 47, 15, 20, 12,
#         24, 44,  3,  2, 33, 45, 48,  5, 34,  2, 18, 24,  1, 38, 34, 15,
#          8, 20, 34, 17,  5, 21, 24,  5, 28, 49, 15,  2, 10, 29, 25, 16,
#         36, 17, 21, 44,  4, 43, 41, 42, 31, 28,  7, 35, 14,  0, 26, 30,
#         31, 30, 22,  4, 10, 11, 42, 45, 46, 21, 43, 39, 24, 32, 48, 37,
#          4, 24, 31, 21]])

# %%
plt.scatter(*data)

# %%
x=np.array([1,2,3,4,5])
data = np.random.randint(0,100,size=(5,))
labels = ['math','physics','chemistry','history']

# %%
plt.barh(x,data,tick_label=labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 plt.barh(x,data,tick_label=labels)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/pyplot.py:2415, in barh(y, width, height, left, align, **kwargs)
#    2413 @_copy_docstring_and_deprecators(Axes.barh)
#    2414 def barh(y, width, height=0.8, left=None, *, align='center', **kwargs):
# -> 2415     return gca().barh(
#    2416         y, width, height=height, left=left, align=align, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py:2551, in Axes.barh(self, y, width, height, left, align, **kwargs)
#    2452 r"""
#    2453 Make a horizontal bar plot.
#    2454
#    (...)
#    2548 .
#    2549 """
#    2550 kwargs.setdefault('orientation', 'horizontal')
# -> 2551 patches = self.bar(x=left, height=height, width=width, bottom=y,
#    2552                    align=align, **kwargs)
#    2553 return patches
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py:2443, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2440 self.add_container(bar_container)
#    2442 if tick_labels is not None:
# -> 2443     tick_labels = np.broadcast_to(tick_labels, len(patches))
#    2444     tick_label_axis.set_ticks(tick_label_position)
#    2445     tick_label_axis.set_ticklabels(tick_labels)
#
# File <__array_function__ internals>:180, in broadcast_to(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/lib/stride_tricks.py:413, in broadcast_to(array, shape, subok)
#     367 @array_function_dispatch(_broadcast_to_dispatcher, module='numpy')
#     368 def broadcast_to(array, shape, subok=False):
#     369     """Broadcast an array to a new shape.
#     370
#     371     Parameters
#    (...)
#     411            [1, 2, 3]])
#     412     """
# --> 413     return _broadcast_to(array, shape, subok=subok, readonly=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/lib/stride_tricks.py:349, in _broadcast_to(array, shape, subok, readonly)
#     346     raise ValueError('all elements of broadcast shape must be non-'
#     347                      'negative')
#     348 extras = []
# --> 349 it = np.nditer(
#     350     (array,), flags=['multi_index', 'refs_ok', 'zerosize_ok'] + extras,
#     351     op_flags=['readonly'], itershape=shape, order='C')
#     352 with it:
#     353     # never really has writebackifcopy semantics
#     354     broadcast = it.itviews[0]
#
# ValueError: operands could not be broadcast together with remapped shapes [original->remapped]: (4,)  and requested shape (5,)

# %%
data = np.random.randint(0,100,size=(20,))

# %%
plt.hist(data,bins=20);

# %%
male_ht = np.random.randint(150,200,size=(50,))
male_wt = np.random.randint(50,110,size=(50,))
female_ht=np.random.randint(130,170,size=(50,))
female_wt=np.random.randint(30,80,size=(50,))

plt.scatter(male_ht,male_wt,label='male',color='skyblue',marker='>')
plt.scatter(female_ht,female_wt,label='female',color='pink',marker='<')
plt.title('Height and Weight')
plt.legend()
plt.xlabel('Height[cm]')
plt.ylabel('Weight[kg]')
plt.xlim(110, 210) 
plt.ylim(20, 120)
# Out:
# (20.0, 120.0)

# %%
data = np.random.randint(0,100,size=(50,2))
plt.plot(data)
plt.savefig('scatter_plot.png')
